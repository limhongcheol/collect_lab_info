# %%
from tabulate import tabulate
import pymysql

conn = pymysql.connect(host="127.0.0.1", user="root", password="1234", db="university_df", charset="utf8")
page_sizes = 10 # 페이지당 보여주는 데이터 개수
tables = [
    "main_info", "researcher", "paper", "professor_subject",
    "project", "recruit", "research_topic", "professor"
]

def print_main_menu():
    print("\n## 연구실 정보 DB 관리 시스템 ##")
    print("(1) Raw 데이터 조회")
    print("(2) 데이터 분석")
    print("(3) 종료\n")

def print_table_menu():
    print("\n[테이블 목록]")
    for i, tbl in enumerate(tables, 1):
        print(f"({i}) {tbl}")
    print(f"({len(tables)+1}) 뒤로가기\n")

def print_crud_menu(selected_table):
    print(f"\n## [{selected_table}] 테이블 관리 ##")
    print("(1) 전체 조회")
    print("(2) 뒤로가기\n")

def select_all(table):
    cur = conn.cursor()
    cur.execute(f"SELECT * FROM {table}")
    rows = cur.fetchall()

    if not rows:
        print(">> 데이터가 없습니다.")
        return

    cur.execute(f"SHOW COLUMNS FROM {table}")
    headers = [col[0] for col in cur.fetchall()]

    page_size = page_sizes
    total_pages = (len(rows) - 1) // page_size + 1
    current_page = 0

    while True:
        start = current_page * page_size
        end = start + page_size
        page_rows = rows[start:end]

        print(f"\n[전체 데이터 조회] - {table} (페이지 {current_page + 1} / {total_pages})")
        print(tabulate(page_rows, headers=headers, tablefmt="grid"))

        if total_pages == 1:
            break

        command = input("\n[n] 다음페이지 | [p] 이전페이지 | [q] 종료: ").lower()

        if command == "n":
            if current_page < total_pages - 1:
                current_page += 1
            else:
                print(">> 마지막 페이지입니다.")
        elif command == "p":
            if current_page > 0:
                current_page -= 1
            else:
                print(">> 첫 페이지입니다.")
        elif command == "q":
            break
        else:
            print(">> 잘못된 명령입니다.")

def analyze_all_columns():
    cur = conn.cursor()
    print("\n[전체 열 및 데이터 개수 분석]")
    result = []
    for table in tables:
        cur.execute(f"SHOW COLUMNS FROM {table}")
        columns = [col[0] for col in cur.fetchall()]
        cur.execute(f"SELECT COUNT(*) FROM {table}")
        count = cur.fetchone()[0]
        result.append([table, ", ".join(columns), count])
    print(tabulate(result, headers=["테이블명", "열 목록", "데이터 개수"], tablefmt="fancy_grid"))

def analyze_professors():
    cur = conn.cursor()
    print("\n[교수별 정보 요약]")
    sql = """
    SELECT p.main_url, p.category, p.name, p.email, p.university, p.phone, p.office_location,
           COALESCE(ps.subjects, '정보없음')
    FROM professor p
    LEFT JOIN professor_subject ps ON p.main_url = ps.main_url AND p.category = ps.category
    ORDER BY p.main_url, p.category
    """
    cur.execute(sql)
    rows = cur.fetchall()
    headers = ["main_url", "category", "name", "email", "university", "phone", "office_location", "subjects"]
    page_size = page_sizes
    current_page = 0
    filtered = rows

    def print_page():
        total_pages = (len(filtered)-1)//page_size + 1
        print(f"\n[교수 정보] (페이지 {current_page+1}/{total_pages})")
        print(tabulate(filtered[current_page*page_size:(current_page+1)*page_size], headers=headers, tablefmt="grid"))

    while True:
        print_page()
        command = input("\n[n] 다음 | [p] 이전 | [f] 필터 | [q] 종료: ").lower()
        if command == "n":
            if (current_page + 1) * page_size < len(filtered): current_page += 1
            else: print(">> 마지막 페이지입니다.")
        elif command == "p":
            if current_page > 0: current_page -= 1
            else: print(">> 첫 페이지입니다.")
        elif command == "f":
            for i, h in enumerate(headers): print(f"({i+1}) {h}")
            col = int(input("열 선택: ")) - 1
            keyword = input("검색어: ")
            filtered = [r for r in rows if keyword.lower() in str(r[col]).lower()]
            current_page = 0
        elif command == "q": break

def show_lab_details(main_url):
    while True:
        print(f"\n[연구실 상세 보기] - {main_url}")
        print("(1) 연구원 정보")
        print("(2) 프로젝트")
        print("(3) 논문")
        print("(4) 뒤로가기")
        choice = input("선택 ==> ")
        if choice == "1": show_researchers(main_url)
        elif choice == "2": show_projects(main_url)
        elif choice == "3": show_papers(main_url)
        elif choice == "4": break


def analyze_research_labs():
    cur = conn.cursor()
    sql = """
    SELECT
    rt.main_url,
    COALESCE(p.name, '정보없음'),
    COALESCE(p.university, '정보없음'),
    GROUP_CONCAT(DISTINCT rt.topic SEPARATOR ', ') AS topics,
    COALESCE(r.info, '정보없음'),
    COALESCE(p.office_location, '정보없음')
    FROM research_topic rt
    LEFT JOIN (
        SELECT p1.*
        FROM professor p1
        INNER JOIN (
            SELECT main_url, MIN(id) AS min_id
            FROM professor
            GROUP BY main_url
        ) p2 ON p1.main_url = p2.main_url AND p1.id = p2.min_id
    ) p ON rt.main_url = p.main_url
    LEFT JOIN (
        SELECT r1.*
        FROM recruit r1
        INNER JOIN (
            SELECT main_url, MIN(id) AS min_id
            FROM recruit
            GROUP BY main_url
        ) r2 ON r1.main_url = r2.main_url AND r1.id = r2.min_id
    ) r ON rt.main_url = r.main_url
    GROUP BY rt.main_url, p.name, p.university, r.info, p.office_location
    ORDER BY rt.main_url
    """
    cur.execute(sql)
    rows = cur.fetchall()
    headers = ["main_url", "name", "university", "topic", "info", "office_location"]
    page_size = page_sizes
    current_page = 0
    filtered = rows

    def print_page():
        total_pages = (len(filtered)-1)//page_size + 1
        print(f"\n[연구실 정보] (페이지 {current_page+1}/{total_pages})")
        numbered = [(i+1,) + row for i, row in enumerate(filtered[current_page*page_size:(current_page+1)*page_size])]
        print(tabulate(numbered, headers=["번호"] + headers, tablefmt="grid"))

    while True:
        print_page()
        command = input("\n[n] 다음 | [p] 이전 | [f] 필터 | [s] 연구실 선택 | [q] 종료: ").lower()
        if command == "n":
            if (current_page + 1) * page_size < len(filtered): current_page += 1
            else: print(">> 마지막 페이지입니다.")
        elif command == "p":
            if current_page > 0: current_page -= 1
            else: print(">> 첫 페이지입니다.")
        elif command == "f":
            for i, h in enumerate(headers): print(f"({i+1}) {h}")
            col = int(input("열 선택: ")) - 1
            keyword = input("검색어: ")
            filtered = [r for r in rows if keyword.lower() in str(r[col]).lower()]
            current_page = 0
        elif command == "s":
            idx = int(input("연구실 번호 선택: ")) - 1
            if 0 <= idx < len(filtered):
                selected = filtered[idx][0]  # main_url
                show_lab_details(selected)
            else:
                print(">> 잘못된 번호입니다.")
        elif command == "q": break


def show_researchers(main_url):
    cur = conn.cursor()
    cur.execute("""
        SELECT name, career_years, field, research_topic, etc FROM researcher WHERE main_url = %s
    """, (main_url,))
    rows = cur.fetchall()
    headers = ["name", "career_years", "field", "research_topic", "etc"]
    page_size = page_sizes
    current_page = 0
    filtered = rows

    def print_page():
        total = (len(filtered)-1)//page_size + 1
        print(f"\n[연구원 정보] (페이지 {current_page+1}/{total})")
        print(tabulate(filtered[current_page*page_size:(current_page+1)*page_size], headers=headers, tablefmt="grid"))

    while True:
        print_page()
        cmd = input("[n] 다음 | [p] 이전 | [f] 필터 | [q] 종료: ").lower()
        if cmd == "n":
            if (current_page + 1) * page_size < len(filtered): current_page += 1
            else: print(">> 마지막 페이지입니다.")
        elif cmd == "p":
            if current_page > 0: current_page -= 1
            else: print(">> 첫 페이지입니다.")
        elif cmd == "f":
            for i, h in enumerate(headers): print(f"({i+1}) {h}")
            col = int(input("열 선택: ")) - 1
            keyword = input("검색어: ")
            filtered = [r for r in rows if keyword.lower() in str(r[col]).lower()]
            current_page = 0
        elif cmd == "q": break

def show_projects(main_url):
    cur = conn.cursor()
    cur.execute("SELECT project_name, project_desc FROM project WHERE main_url = %s", (main_url,))
    rows = cur.fetchall()
    paginate_simple(rows, ["project_name", "project_desc"], "프로젝트", main_url)

def show_papers(main_url):
    cur = conn.cursor()
    cur.execute("SELECT paper_title, journal, author, year FROM paper WHERE main_url = %s", (main_url,))
    rows = cur.fetchall()
    paginate_simple(rows, ["paper_title", "journal", "author", "year"], "논문", main_url)

def paginate_simple(rows, headers, title, main_url):
    page_size = page_sizes
    current_page = 0
    def print_page():
        total = (len(rows)-1)//page_size + 1
        print(f"\n[{title}] - {main_url} (페이지 {current_page+1}/{total})")
        print(tabulate(rows[current_page*page_size:(current_page+1)*page_size], headers=headers, tablefmt="grid"))
    while True:
        print_page()
        cmd = input("[n] 다음 | [p] 이전 | [q] 종료: ").lower()
        if cmd == "n":
            if (current_page + 1) * page_size < len(rows): current_page += 1
            else: print(">> 마지막 페이지입니다.")
        elif cmd == "p":
            if current_page > 0: current_page -= 1
            else: print(">> 첫 페이지입니다.")
        elif cmd == "q": break

def show_analysis_menu():
    while True:
        print("\n## 데이터 분석 기능 ##")
        print("(1) 전체 열 분석 (테이블별 열 및 데이터 수)")
        print("(2) 교수님별 정보 요약")
        print("(3) 연구실별 내용 요약")
        print("(4) 뒤로가기\n")
        choice = input("선택하세요 ==> ")

        if choice == "1": analyze_all_columns()
        elif choice == "2": analyze_professors()
        elif choice == "3": analyze_research_labs()
        elif choice == "4": break

# === MAIN LOOP ===
while True:
    print_main_menu()
    menu = input("선택하세요 ==> ")
    if menu == "1":
        while True:
            print_table_menu()
            table_choice = input("테이블 선택 ==> ")
            if table_choice == str(len(tables)+1): break
            if not table_choice.isdigit() or int(table_choice) < 1 or int(table_choice) > len(tables):
                print(">> 올바른 번호를 입력해주세요.")
                continue
            selected_table = tables[int(table_choice)-1]
            while True:
                print_crud_menu(selected_table)
                crud = input("선택하세요 ==> ")
                if crud == "1": select_all(selected_table)
                elif crud == "2": break
                else: print(">> 잘못된 입력입니다.")
    elif menu == "2": show_analysis_menu()
    elif menu == "3": break
    else: print(">> 잘못된 입력입니다.")

conn.close()
print("프로그램 종료~")
# Out:
# ## 연구실 정보 DB 관리 시스템 ##
# (1) Raw 데이터 조회
# (2) 데이터 분석
# (3) 종료
#
#
# ## 데이터 분석 기능 ##
# (1) 전체 열 분석 (테이블별 열 및 데이터 수)
# (2) 교수님별 정보 요약
# (3) 연구실별 내용 요약
# (4) 뒤로가기
#
#
# [연구실 정보] (페이지 1/11)
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |   번호 | main_url                    | name            | university           | topic                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                | info                                                                                                                                                                                                                             | office_location        |
# +========+=============================+=================+======================+======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================+==================================================================================================================================================================================================================================+========================+
# |      1 | http://airlab.khu.ac.kr/    | 정보없음        | 정보없음             | 경희대학교 AIRLab은 딥러닝 알고리즘, 시퀀스 모델링, 인공지능 기반 렌더링, 로보틱스 시뮬레이션, 그리고 최신 인공지능 모델(Mamba, Segment Anything 등)을 활용한 연구를 수행하고 있습니다., 이 연구실은 360° 파노라마 이미지와 LiDAR 포인트 클라우드 데이터를 결합한 데이터셋을 구축하여 관련 연구를 수행하고 있습니다., 이 연구실은 컴퓨터 비전과 머신러닝을 기반으로 인공지능 및 로봇 기술을 연구하며, 자율주행차, 로봇, 다양한 AI 시스템 등 여러 분야에 적용하는 것을 목표로 합니다.                                                                                                                                                                                                                                                                                 | 정보없음                                                                                                                                                                                                                         | 정보없음               |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |      2 | http://airlab.sogang.ac.kr/ | Youngwook Kim   | Sogang University    | 이 연구실은 딥러닝과 양자 컴퓨팅을 활용하여 표적 탐지, 추적, 분류, 생체 신호 감지, 레이더 신호 처리, RF 하드웨어 시스템 및 안테나 설계 등 다양한 분야의 연구를 수행하고 있습니다., 이 연구실은 딥러닝과 양자 컴퓨팅을 활용하여 표적 탐지, 추적, 분류, 생체 신호 분석, 레이더 신호 처리, RF 하드웨어 시스템 및 안테나 설계 등 다양한 분야의 연구를 수행하고 있습니다., 이 연구실은 레이더 기술과 머신러닝/딥러닝을 결합하여 인간 움직임 분류, 표적 탐지/추적/분류, 생체 감지, RF 시스템 및 안테나 설계, 양자 어닐링 기반 신호 처리 등 다양한 연구를 수행하며, 보안, 의료, 인간-기계 인터페이스 등 다양한 분야에 응용하는 것을 목표로 합니다.                                                                                                                          | 정보없음                                                                                                                                                                                                                         | 미상                   |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |      3 | http://ave.kaist.ac.kr/     | Seung-Hyun Kong | 미상                 | 이 연구실은 자율 주행 시스템, 학습 기반 엔드 투 엔드(E2E) 방식, 그리고 고정밀 위치 추정 시스템 관련 연구를 수행하고 있습니다., 이 연구실은 자율 주행 시스템, 학습 기반 엔드투엔드(E2E) 방식, 그리고 고정밀 위치 추정 시스템 관련 연구를 수행하고 있습니다., 이 연구실은 자율주행 시스템, 학습 기반 엔드투엔드(E2E) 방식, 그리고 고정밀 위치 측정 시스템 관련 연구를 수행하고 있습니다., 이 연구실은 자율주행 시스템과 학습 기반 엔드투엔드(E2E) 방식, 그리고 고정밀 위치 측정 시스템 관련 연구를 수행하고 있습니다., 이 연구실은 학습 기반의 엔드투엔드(E2E) 자율 주행 시스템 및 고정밀 위치 측정 기술 개발을 위한 연구를 수행하고 있습니다.                                                                                                                         | 정보없음                                                                                                                                                                                                                         | 미상                   |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |      4 | http://bcml.kw.ac.kr/       | 정보없음        | 정보없음             | 이 연구실은 뇌 과학 및 생명 과학 지식을 기반으로 3세대 뉴로모픽 모델 개발, 강화 학습 기반 모델 최적화 및 로봇 제어, 의료 AI 및 설명 가능한 AI(XAI) 연구를 수행하고 있습니다.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         | 정보없음                                                                                                                                                                                                                         | 정보없음               |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |      5 | http://bic.kw.ac.kr/index   | Joon Sub Shim   | Kwangwoon University | 이 연구실은 생체 의료 기기와 미세/나노 기술의 최첨단 발전을 목표로 스마트 바이오칩, 마이크로 유체 장치, 웨어러블 전극 기반 장치 등 다양한 연구를 수행하며, 상용화를 위한 생산, 측정, 평가 연구를 적극적으로 진행하고 있습니다., 이 연구실은 스마트 마이크로 유체 장치, 웨어러블 생체 의료 기기, IoD 기기, 나노 조립, 나노 제작, 나노-바이오, 나노 에너지 등 다양한 분야를 연구하며, 특히 웨어러블 생체 신호 측정용 유연한 전기극 개발에 집중하고 있습니다., 이 연구실은 스마트 마이크로 유체 장치, 웨어러블 생체 의료 장치, IoD (In-Vitro Diagnostics) 장치, 나노 조립, 나노 제작, 나노-바이오, 나노 에너지 등 다양한 분야의 연구를 수행하며, 특히 IoD 진단 장치 개발에 집중하고 있습니다., 이 연구실은 스마트 마이크로 유체 장치, 웨어러블 생체 의료 장치, IoD 장치 | 정보없음                                                                                                                                                                                                                         | Chambit-Bldg, Room 609 |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |      6 | http://ddps.cloud/          | 정보없음        | 정보없음             | 이 연구실은 분산 데이터 처리 시스템, 엣지 컴퓨팅 환경에서의 딥러닝 작업 스케줄링, 클라우드 로그 수집 및 분석, 그리고 관련 시스템 설정 및 API 활용 연구를 수행하고 있습니다., 이 연구실은 인공지능 및 빅데이터 처리를 위한 고성능, 저비용, 사용 편의성을 갖춘 클라우드 컴퓨팅 시스템 개발에 주력하고 있습니다.                                                                                                                                                                                                                                                                                                                                                                                                                                                        | 정보없음                                                                                                                                                                                                                         | 정보없음               |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |      7 | http://eealab.cau.ac.kr/    | JONGSUK RO      | 중앙대학교           | 이 연구실은 재료, 기구, 생산을 고려한 전기기기 해석 및 최적설계, 다중물리 특성 해석, 성능/가격 동시 최적화 연구를 수행하고 있습니다., 이 연구실은 전자기, 압전 현상을 활용한 변압기 분석 및 최적 설계 연구를 수행하고 있습니다., 이 연구실은 전자기, 압전, 형상기억합금 등을 활용한 발전기 및 에너지 하베스터 개발 연구를 수행하고 있습니다., 이 연구실은 전자기, 자왜, 압전 현상을 활용한 전기기기 및 모터, 발전기, 변압기 등의 분석 및 최적 설계 연구를 수행하고 있습니다., 이 연구실은 전자기기 및 전기 기기를 분석하고 최적화하는 방법론 연구, 전자기기 모터, 특수 모터, 발전기, 변압기 관련 연구를 수행하고 있습니다., 이 연구실은 전자기기 해석 및 최적 설계 기법, 특히 전자기기(모터, 발전기, 변압기 등)의 성능 분석 및 최적화 연구를 수행하고 있             | 전기기기연구실은 전자기계 분야에 대한 깊이 있는 연구를 진행하고, 자율적인 연구 참여와 다양한 지원 혜택을 제공하며, 특히 LG전자 타겟랩 특전까지 누릴 수 있는 대학원 진학 또는 연구 인턴십에 관심 있는 학생들을 모집하고 있습니다. | 미상                   |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |      8 | http://hifiai.pe.kr/        | 김성환          | 건국대학교           | HIFIAI 연구실은 영상 기반 인공지능, 통계적 인공지능 알고리즘, 빅데이터 분석 방법론 등을 활용하여 재활용 쓰레기 탐지 자동화, 비대면 본인 인증, 환경 유해 물질 모니터링, 미세먼지 측정 기술 개발 등 다양한 분야의 연구를 수행하고 있습니다., 이 연구실은 인공지능 분야의 미래 지향적인 연구를 수행하고 있습니다.                                                                                                                                                                                                                                                                                                                                                                                                                                                       | 연구실은 현재 능력보다는 장기적인 관점에서 꾸준히 성장하고, 변화하는 기술과 산업에 유연하게 대응하며 지속적으로 도전하는 학생들을 찾고 있습니다.                                                                                 | 미상                   |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |      9 | http://iesl.inha.ac.kr/     | Deok-Hwan Kim   | Inha University      | 이 연구실은 임베디드 엣지 컴퓨팅과 예술 분야를 주요 연구 주제로 다루고 있습니다., 이 연구실은 임베디드 엣지 컴퓨팅과 예술 분야의 연구를 수행하고 있습니다.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           | 정보없음                                                                                                                                                                                                                         | 미상                   |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |     10 | http://infosec.pusan.ac.kr/ | 정보없음        | 정보없음             | 이 연구실은 AI 기반 보안, 산업용 AI, 자연어 처리, 블록체인, 양자 컴퓨팅 등 다양한 분야에서 특히 적대적 공격 및 방어 기술 연구와 그래픽 엔진 기반 3D 공격/방어 시뮬레이션 시스템 구축에 집중하고 있습니다., 이 연구실은 AI 기반 자연어처리, 특히 초거대 언어 모델(LLM)의 경량화, 효율적인 학습 기법, 그리고 LLM 기반 서비스 연구를 수행하고 있습니다., 이 연구실은 AI보안, 산업용 AI, 자연어처리, 블록체인, 양자컴퓨팅 및 암호 해독 등 다양한 분야의 연구를 수행하고 있습니다., 이 연구실은 AI보안, 산업용 AI, 자연어처리, 블록체인, 양자컴퓨팅 및 암호 해독 분야를 중심으로, 관련 기술을 활용한 다양한 연구 및 개발을 수행하고 있습니다., 이 연구실은 AI보안, 자연어처리, 블록체인, 양자컴퓨팅 등 다양한 분야에서 연구를 진행하며, 특히 블록체인 기술을 활용하여     | 연구실은 AI, 보안, 블록체인, 양자컴퓨팅 등 첨단 기술 분야에 대한 깊이 있는 연구를 수행할 잠재력과 열정을 가진 대학원생을 모집하는 것으로 보입니다.                                                                               | 정보없음               |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
#
# [연구실 정보] (페이지 1/11)
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |   번호 | main_url                    | name            | university           | topic                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                | info                                                                                                                                                                                                                             | office_location        |
# +========+=============================+=================+======================+======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================+==================================================================================================================================================================================================================================+========================+
# |      1 | http://airlab.khu.ac.kr/    | 정보없음        | 정보없음             | 경희대학교 AIRLab은 딥러닝 알고리즘, 시퀀스 모델링, 인공지능 기반 렌더링, 로보틱스 시뮬레이션, 그리고 최신 인공지능 모델(Mamba, Segment Anything 등)을 활용한 연구를 수행하고 있습니다., 이 연구실은 360° 파노라마 이미지와 LiDAR 포인트 클라우드 데이터를 결합한 데이터셋을 구축하여 관련 연구를 수행하고 있습니다., 이 연구실은 컴퓨터 비전과 머신러닝을 기반으로 인공지능 및 로봇 기술을 연구하며, 자율주행차, 로봇, 다양한 AI 시스템 등 여러 분야에 적용하는 것을 목표로 합니다.                                                                                                                                                                                                                                                                                 | 정보없음                                                                                                                                                                                                                         | 정보없음               |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |      2 | http://airlab.sogang.ac.kr/ | Youngwook Kim   | Sogang University    | 이 연구실은 딥러닝과 양자 컴퓨팅을 활용하여 표적 탐지, 추적, 분류, 생체 신호 감지, 레이더 신호 처리, RF 하드웨어 시스템 및 안테나 설계 등 다양한 분야의 연구를 수행하고 있습니다., 이 연구실은 딥러닝과 양자 컴퓨팅을 활용하여 표적 탐지, 추적, 분류, 생체 신호 분석, 레이더 신호 처리, RF 하드웨어 시스템 및 안테나 설계 등 다양한 분야의 연구를 수행하고 있습니다., 이 연구실은 레이더 기술과 머신러닝/딥러닝을 결합하여 인간 움직임 분류, 표적 탐지/추적/분류, 생체 감지, RF 시스템 및 안테나 설계, 양자 어닐링 기반 신호 처리 등 다양한 연구를 수행하며, 보안, 의료, 인간-기계 인터페이스 등 다양한 분야에 응용하는 것을 목표로 합니다.                                                                                                                          | 정보없음                                                                                                                                                                                                                         | 미상                   |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |      3 | http://ave.kaist.ac.kr/     | Seung-Hyun Kong | 미상                 | 이 연구실은 자율 주행 시스템, 학습 기반 엔드 투 엔드(E2E) 방식, 그리고 고정밀 위치 추정 시스템 관련 연구를 수행하고 있습니다., 이 연구실은 자율 주행 시스템, 학습 기반 엔드투엔드(E2E) 방식, 그리고 고정밀 위치 추정 시스템 관련 연구를 수행하고 있습니다., 이 연구실은 자율주행 시스템, 학습 기반 엔드투엔드(E2E) 방식, 그리고 고정밀 위치 측정 시스템 관련 연구를 수행하고 있습니다., 이 연구실은 자율주행 시스템과 학습 기반 엔드투엔드(E2E) 방식, 그리고 고정밀 위치 측정 시스템 관련 연구를 수행하고 있습니다., 이 연구실은 학습 기반의 엔드투엔드(E2E) 자율 주행 시스템 및 고정밀 위치 측정 기술 개발을 위한 연구를 수행하고 있습니다.                                                                                                                         | 정보없음                                                                                                                                                                                                                         | 미상                   |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |      4 | http://bcml.kw.ac.kr/       | 정보없음        | 정보없음             | 이 연구실은 뇌 과학 및 생명 과학 지식을 기반으로 3세대 뉴로모픽 모델 개발, 강화 학습 기반 모델 최적화 및 로봇 제어, 의료 AI 및 설명 가능한 AI(XAI) 연구를 수행하고 있습니다.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         | 정보없음                                                                                                                                                                                                                         | 정보없음               |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |      5 | http://bic.kw.ac.kr/index   | Joon Sub Shim   | Kwangwoon University | 이 연구실은 생체 의료 기기와 미세/나노 기술의 최첨단 발전을 목표로 스마트 바이오칩, 마이크로 유체 장치, 웨어러블 전극 기반 장치 등 다양한 연구를 수행하며, 상용화를 위한 생산, 측정, 평가 연구를 적극적으로 진행하고 있습니다., 이 연구실은 스마트 마이크로 유체 장치, 웨어러블 생체 의료 기기, IoD 기기, 나노 조립, 나노 제작, 나노-바이오, 나노 에너지 등 다양한 분야를 연구하며, 특히 웨어러블 생체 신호 측정용 유연한 전기극 개발에 집중하고 있습니다., 이 연구실은 스마트 마이크로 유체 장치, 웨어러블 생체 의료 장치, IoD (In-Vitro Diagnostics) 장치, 나노 조립, 나노 제작, 나노-바이오, 나노 에너지 등 다양한 분야의 연구를 수행하며, 특히 IoD 진단 장치 개발에 집중하고 있습니다., 이 연구실은 스마트 마이크로 유체 장치, 웨어러블 생체 의료 장치, IoD 장치 | 정보없음                                                                                                                                                                                                                         | Chambit-Bldg, Room 609 |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |      6 | http://ddps.cloud/          | 정보없음        | 정보없음             | 이 연구실은 분산 데이터 처리 시스템, 엣지 컴퓨팅 환경에서의 딥러닝 작업 스케줄링, 클라우드 로그 수집 및 분석, 그리고 관련 시스템 설정 및 API 활용 연구를 수행하고 있습니다., 이 연구실은 인공지능 및 빅데이터 처리를 위한 고성능, 저비용, 사용 편의성을 갖춘 클라우드 컴퓨팅 시스템 개발에 주력하고 있습니다.                                                                                                                                                                                                                                                                                                                                                                                                                                                        | 정보없음                                                                                                                                                                                                                         | 정보없음               |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |      7 | http://eealab.cau.ac.kr/    | JONGSUK RO      | 중앙대학교           | 이 연구실은 재료, 기구, 생산을 고려한 전기기기 해석 및 최적설계, 다중물리 특성 해석, 성능/가격 동시 최적화 연구를 수행하고 있습니다., 이 연구실은 전자기, 압전 현상을 활용한 변압기 분석 및 최적 설계 연구를 수행하고 있습니다., 이 연구실은 전자기, 압전, 형상기억합금 등을 활용한 발전기 및 에너지 하베스터 개발 연구를 수행하고 있습니다., 이 연구실은 전자기, 자왜, 압전 현상을 활용한 전기기기 및 모터, 발전기, 변압기 등의 분석 및 최적 설계 연구를 수행하고 있습니다., 이 연구실은 전자기기 및 전기 기기를 분석하고 최적화하는 방법론 연구, 전자기기 모터, 특수 모터, 발전기, 변압기 관련 연구를 수행하고 있습니다., 이 연구실은 전자기기 해석 및 최적 설계 기법, 특히 전자기기(모터, 발전기, 변압기 등)의 성능 분석 및 최적화 연구를 수행하고 있             | 전기기기연구실은 전자기계 분야에 대한 깊이 있는 연구를 진행하고, 자율적인 연구 참여와 다양한 지원 혜택을 제공하며, 특히 LG전자 타겟랩 특전까지 누릴 수 있는 대학원 진학 또는 연구 인턴십에 관심 있는 학생들을 모집하고 있습니다. | 미상                   |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |      8 | http://hifiai.pe.kr/        | 김성환          | 건국대학교           | HIFIAI 연구실은 영상 기반 인공지능, 통계적 인공지능 알고리즘, 빅데이터 분석 방법론 등을 활용하여 재활용 쓰레기 탐지 자동화, 비대면 본인 인증, 환경 유해 물질 모니터링, 미세먼지 측정 기술 개발 등 다양한 분야의 연구를 수행하고 있습니다., 이 연구실은 인공지능 분야의 미래 지향적인 연구를 수행하고 있습니다.                                                                                                                                                                                                                                                                                                                                                                                                                                                       | 연구실은 현재 능력보다는 장기적인 관점에서 꾸준히 성장하고, 변화하는 기술과 산업에 유연하게 대응하며 지속적으로 도전하는 학생들을 찾고 있습니다.                                                                                 | 미상                   |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |      9 | http://iesl.inha.ac.kr/     | Deok-Hwan Kim   | Inha University      | 이 연구실은 임베디드 엣지 컴퓨팅과 예술 분야를 주요 연구 주제로 다루고 있습니다., 이 연구실은 임베디드 엣지 컴퓨팅과 예술 분야의 연구를 수행하고 있습니다.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           | 정보없음                                                                                                                                                                                                                         | 미상                   |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
# |     10 | http://infosec.pusan.ac.kr/ | 정보없음        | 정보없음             | 이 연구실은 AI 기반 보안, 산업용 AI, 자연어 처리, 블록체인, 양자 컴퓨팅 등 다양한 분야에서 특히 적대적 공격 및 방어 기술 연구와 그래픽 엔진 기반 3D 공격/방어 시뮬레이션 시스템 구축에 집중하고 있습니다., 이 연구실은 AI 기반 자연어처리, 특히 초거대 언어 모델(LLM)의 경량화, 효율적인 학습 기법, 그리고 LLM 기반 서비스 연구를 수행하고 있습니다., 이 연구실은 AI보안, 산업용 AI, 자연어처리, 블록체인, 양자컴퓨팅 및 암호 해독 등 다양한 분야의 연구를 수행하고 있습니다., 이 연구실은 AI보안, 산업용 AI, 자연어처리, 블록체인, 양자컴퓨팅 및 암호 해독 분야를 중심으로, 관련 기술을 활용한 다양한 연구 및 개발을 수행하고 있습니다., 이 연구실은 AI보안, 자연어처리, 블록체인, 양자컴퓨팅 등 다양한 분야에서 연구를 진행하며, 특히 블록체인 기술을 활용하여     | 연구실은 AI, 보안, 블록체인, 양자컴퓨팅 등 첨단 기술 분야에 대한 깊이 있는 연구를 수행할 잠재력과 열정을 가진 대학원생을 모집하는 것으로 보입니다.                                                                               | 정보없음               |
# +--------+-----------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+
#
# [연구실 상세 보기] - http://airlab.khu.ac.kr/
# (1) 연구원 정보
# (2) 프로젝트
# (3) 논문
# (4) 뒤로가기
